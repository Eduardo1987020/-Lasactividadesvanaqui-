# %%
nombre=str(input("Ingrese su nombre: "))
if nombre!="Ana" and nombre!="Eduardo" and nombre!="Pedro":
  print("Hola",nombre)
# Out:
# Ingrese su nombre: eduardo
# Hola eduardo

# %%
lista=[2,4,5,7,4,7,8]
print("El último elemento es: ",lista[-1])
print("Lista original: ")
print(lista)
print("Lista revertida: ")
contador = len(lista) - 1
nuevaLista = []
while (contador >= 0):
  nuevaLista.append(lista[contador])
  contador = contador - 1
print(nuevaLista)
# Out:
# El último elemento es:  8
# Lista original:
# [2, 4, 5, 7, 4, 7, 8]
# Lista revertida:
# [8, 7, 4, 7, 5, 4, 2]

# %%
lista=["Hola","a","todos","esto","es","un","marco"]
print("***\n* ",lista[0]," * \n* ",lista[1],"    \n ",lista[2],"\n ",lista[3]," \n ",lista[4], "   \n ",lista[5],"   \n ",lista[6],"\n****"   )
# Out:
# ***
# *  Hola  *
# *  a
#   todos
#   esto
#   es
#   un
#   marco
# ****
